# %%
import pandas as pd

# %%
df = pd.read_csv('experiments/extractive-qa/task2report.csv')
df.head()
# Out:
#           Model Dataset Language           Task  Exact Match     F1
# 0        gemma2  SQUAD1       en  extractive-qa        75.73  87.19
# 1      llama3.1  SQUAD1       en  extractive-qa        70.39  82.64
# 2  mistral-nemo  SQUAD1       en  extractive-qa        67.48  83.35
# 3        gemma2  SQUAD2       en  extractive-qa        63.85  69.80
# 4      llama3.1  SQUAD2       en  extractive-qa        48.82  56.25

# %%
# drop columns Dataset and Language
df = df.drop(columns=['Dataset', 'Language'])
df.head()
# Out:
#           Model           Task  Exact Match     F1
# 0        gemma2  extractive-qa        75.73  87.19
# 1      llama3.1  extractive-qa        70.39  82.64
# 2  mistral-nemo  extractive-qa        67.48  83.35
# 3        gemma2  extractive-qa        63.85  69.80
# 4      llama3.1  extractive-qa        48.82  56.25

# %%
df2 = df.groupby(['Task', 'Model']).mean().reset_index().round(2)
df2
# Out:
#                Task         Model  Exact Match     F1
# 0     extractive-qa        gemma2        66.53  79.41
# 1     extractive-qa      llama3.1        56.04  70.64
# 2     extractive-qa  mistral-nemo        55.21  72.39
# 3  template-filling        gemma2        36.69  36.70
# 4  template-filling      llama3.1        40.62  40.63
# 5  template-filling       mistral        23.86  23.87

# %%
df2.to_csv('experiments/extractive-qa/task2report_aggregated.csv', index=False)

# %%
from datasets import load_dataset

# %%
a = "Tim"
b = "im"

b in a
# Out:
# True

# %%
squad2 = load_dataset("squad_v2")
# Out:
# Downloading readme:   0%|          | 0.00/8.92k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/16.4M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/130319 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
squad2["validation"].to_pandas()[5:9]
# Out:
#                          id    title  \
# 5  5ad39d53604f3c001a3fe8d1  Normans
# 6  5ad39d53604f3c001a3fe8d2  Normans
# 7  5ad39d53604f3c001a3fe8d3  Normans
# 8  5ad39d53604f3c001a3fe8d4  Normans
#
#                                              context  \
# 5  The Normans (Norman: Nourmands; French: Norman...
# 6  The Normans (Norman: Nourmands; French: Norman...
# 7  The Normans (Norman: Nourmands; French: Norman...
# 8  The Normans (Norman: Nourmands; French: Norman...
#
#                                             question  \
# 5  Who gave their name to Normandy in the 1000's ...
# 6                        What is France a region of?
# 7          Who did King Charles III swear fealty to?
# 8             When did the Frankish identity emerge?
#
#                             answers
# 5  {'text': [], 'answer_start': []}
# 6  {'text': [], 'answer_start': []}
# 7  {'text': [], 'answer_start': []}
# 8  {'text': [], 'answer_start': []}

# %%
squad = load_dataset("squad")

# %%
type(squad["validation"])
# Out:
# datasets.arrow_dataset.Dataset

# %%
squad = load_dataset("squad", split="train[:5000]")

# %%
from ollama import Client
client = Client(host='http://localhost:19290')
client.list()

# %%
user_prompt = """
Please extract the answer to the following question from the text below:

Context: {}
Question: {}

Please answer in this format. You are not required to provide any reasoning for your answer.
Answer: <answer>
Reasoning: <reasoning>

Remember, the answer must be verbatim from the text. You have to extract the answer from the text, not generate it.
"""

# %%
import re
from typing import Optional, Tuple


answer_word = "Answer"
reasoning_word = "Reasoning"

def parse_response(response: str) -> Tuple[Optional[str], str]:
    # Check if the response is in the correct format.
    if not response.startswith(f"{answer_word}: "):
        return None, "Answer has not been provided"
    
    if "\n" in response:
        # reasoning has been provided
        components = re.split(r"\n+", response)

        # extract the answer
        answer = components[0].split(": ")[1].strip()

        # exctract the reasoning
        if not components[1].startswith(f"{reasoning_word}:"):
            return answer, f"The reasoning has to start with '{reasoning_word}:'."

        reasoning = components[1].split(": ")[1]
        return answer, reasoning

    else:
        # reasoning has not been provided
        answer = response.split(": ")[1].strip()
        return answer, "Reasoning has not been provided"

# %%
def compute_f1(prediction: str, gold: str) -> float:
    prediction_tokens = prediction.lower().split()
    true_tokens = gold.lower().split()
    common_tokens = set(prediction_tokens) & set(true_tokens)
    if len(common_tokens) == 0:
        return 0
    precision = len(common_tokens) / len(prediction_tokens)
    recall = len(common_tokens) / len(true_tokens)
    return 2 * (precision * recall) / (precision + recall)

# %%
def compute_em(prediction: str, gold: str) -> float:
    return float(prediction.lower() == gold.lower())

# %%
from typing import List, Tuple
import numpy as np


def eval(predictions: List[str], golds: List[str]) -> Tuple[float, float]:
    f1_scores = []
    em_scores = []
    for prediction, gold in zip(predictions, golds):
        f1_scores.append(compute_f1(prediction, gold))
        em_scores.append(compute_em(prediction, gold))
    return np.mean(f1_scores), np.mean(em_scores)

# %%
from tqdm import tqdm


questions = squad["question"][:10]
contexts = squad["context"][:10]
answers = [answer["text"][0] for answer in squad["answers"][:10]]
predictions = []
for i in tqdm(range(10), desc="Evaluating"):
    response = client.chat(model='gemma2', messages=[
      {
          'role': 'system',
          'content': 'You are a system to support the analysis of large amounts of text. You will assist the user by answering all questions correctly.',
      },
      {
        'role': 'user',
        'content': user_prompt.format(contexts[i], questions[i]).strip(),
      },
    ])
    prediction, reasoning = parse_response(response["message"]["content"])
    predictions.append(prediction)

    print(f"Question: {questions[i]}")
    print(f"Prediction: {prediction}")
    print(f"Answer: {answers[i]}")
    print(f"Reasoning: {reasoning}")
    print()

# %%
print("Evaluation:")
f1, em = eval(predictions, answers)
print(f"F1: {f1}")
print(f"EM: {em}")

# %%
from datasets import load_dataset

# %%
germanquad = load_dataset("deepset/germanquad")

# %%
germanquad

# %%
df = germanquad["test"].to_pandas()
df[100:150]
# Out:
#         id                                            context  \
# 100  41225  Gletscher\n\n=== Gleichgewichtslinie ===\nDie ...
# 101  41226  Gletscher\n\n=== Gleichgewichtslinie ===\nDie ...
# 102  41228  Gletscher\n\n=== Gleichgewichtslinie ===\nDie ...
# 103  41229  Gletscher\n\n=== Gleichgewichtslinie ===\nDie ...
# 104  41227  Gletscher\n\n=== Gleichgewichtslinie ===\nDie ...
# 105  41230  Gletscher\n\n=== Gleichgewichtslinie ===\nDie ...
# 106  41279  Osmanisches_Reich\n\n=== Reform des Millet-Sys...
# 107  41280  Osmanisches_Reich\n\n=== Reform des Millet-Sys...
# 108  41282  Osmanisches_Reich\n\n=== Reform des Millet-Sys...
# 109  41283  Osmanisches_Reich\n\n=== Reform des Millet-Sys...
# 110  41284  Osmanisches_Reich\n\n=== Reform des Millet-Sys...
# 111  41285  Osmanisches_Reich\n\n=== Reform des Millet-Sys...
# 112  41288  Osmanisches_Reich\n\n=== Reform des Millet-Sys...
# 113  41290  Tschechische_Sprache\n\n=== Deklination ===\nT...
# 114  41291  Tschechische_Sprache\n\n=== Deklination ===\nT...
# 115  41292  Tschechische_Sprache\n\n=== Deklination ===\nT...
# 116  41293  Tschechische_Sprache\n\n=== Deklination ===\nT...
# 117  41294  Tschechische_Sprache\n\n=== Deklination ===\nT...
# 118  41295  Tschechische_Sprache\n\n=== Deklination ===\nT...
# 119  41296  American_Standard_Code_for_Information_Interch...
# 120  41297  American_Standard_Code_for_Information_Interch...
# 121  41299  American_Standard_Code_for_Information_Interch...
# 122  41301  American_Standard_Code_for_Information_Interch...
# 123  41349  FC_Barcelona\n\n=== Zweifacher Ligagewinn und ...
# 124  41350  FC_Barcelona\n\n=== Zweifacher Ligagewinn und ...
# 125  41364  Kondensator__Elektrotechnik_\n\n==== Kennzeich...
# 126  41366  United_States_Army\nDie ''United States Army''...
# 127  41367  United_States_Army\nDie ''United States Army''...
# 128  41368  United_States_Army\nDie ''United States Army''...
# 129  41369  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 130  41370  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 131  41371  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 132  41372  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 133  41373  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 134  41374  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 135  41375  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 136  41376  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 137  41377  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 138  41378  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 139  41379  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 140  41380  Zhejiang\n\n== Geographie ==\nZhejiang liegt s...
# 141  41391  Gletscher\n\n=== Eisfließen; Deformationsfließ...
# 142  41392  Gletscher\n\n=== Eisfließen; Deformationsfließ...
# 143  41393  Gletscher\n\n=== Eisfließen; Deformationsfließ...
# 144  38513  Houston\n\n== Geografie ==\nHouston liegt an d...
# 145  38514  Houston\n\n== Geografie ==\nHouston liegt an d...
# 146  38515  Houston\n\n== Geografie ==\nHouston liegt an d...
# 147  38516  Houston\n\n== Geografie ==\nHouston liegt an d...
# 148  38517  Houston\n\n== Geografie ==\nHouston liegt an d...
# 149  38518  Houston\n\n== Geografie ==\nHouston liegt an d...
#
#                                               question  \
# 100  Was ist der Fachbegriff für die Gleichgewichts...
# 101  Was wird als Gleichgewichtslinie eines Gletsch...
# 102   Wie ist das Zehrgebiet des Gletschers definiert?
# 103  Wie heißt der Bereich oberhalb der Gleichgewic...
# 104  Wie heißt der Bereich unterhalb der Gleichgewi...
# 105  Wie ist das Akkumulationsgebiet des Gletschers...
# 106  In welchem Edikt wurde im osmanischen Reich di...
# 107         Wann wurde das Edikt von Gülhane erlassen?
# 108            Wann wurde der Hatt-i Hümayun erlassen?
# 109  Wann wurde die griechische Bevölkerung aus dem...
# 110  Welches Gesetz war Grundlage für den Genozid a...
# 111  Welche Volksgruppe wurde 1915 im Osmanischen R...
# 112  Welche Gruppe mit nationalistischen Ideen erla...
# 113          Wie viele Kasus gibt es im Tschechischen?
# 114  Wie viele grammatische Geschlechter gibt es im...
# 115            Welche Genera gibt es im Tschechischen?
# 116  Zwischen was wird im Tschechischen beim männli...
# 117           Welche Artikel gibt es im Tschechischen?
# 118  Wozu dient die Kurzform von Adjektiven im Tsch...
# 119                       Wann wurde ASCII eingeführt?
# 120                   Wie viele Zeichen umfasst ASCII?
# 121                   Welche Buchstaben umfasst ASCII?
# 122     Wie viele Steuerzeichen gibt es im ASCII-Code?
# 123  Für wie viel Geld wurde Neymar zu Paris Saint ...
# 124  In welcher Mannschaft spielte Ousman Dembélé, ...
# 125  Welche Art von Kondensatoren wurden mit "cm" g...
# 126     In welchem Jahr wurde die US-Army aufgestellt?
# 127                 Was sind die Aufgaben der US-Army?
# 128  Welche Armeen der Welt haben mehr Mann als die...
# 129          In welchem Teil von China liegt Zhejiang?
# 130                   Woran grenzt Zhejiang im Norden?
# 131                    Woran grenzt Zhejiang im Osten?
# 132                    Was liegt südlich von Zhejiang?
# 133          In welche Zonen wird Zhejiang gegliedert?
# 134  Wie viel Prozent der Fläche von Zhejiang bilde...
# 135                  Wie viele Bergketen hat Zhejiang?
# 136        Wie hoch ist der höchste Punkt in Zhejiang?
# 137             Was ist der höchste Punkt in Zhejiang?
# 138               Welche Flüsse verlaufen in Zhejiang?
# 139        Welche natürliche Seen gibt es in Zhejiang?
# 140              Wie viele Inseln gibt es in Zhejiang?
# 141     Wie sieht die molekulare Struktur von Eis aus?
# 142  In welchem Fall bewegt sich die obere Gletsche...
# 143  Warum ist die Fließgeschwindigkeit verschieden...
# 144              In welchem Bundesstaat liegt Houston?
# 145                                  Wo liegt Houston?
# 146  Wie viel der Fläche von Houston besteht aus Wa...
# 147                   In welchem County liegt Houston?
# 148        Wie heißt der Schifffahrtskanal in Houston?
# 149     Wie heißt der Fluss, der durch Houston fließt?
#
#                                                answers
# 100  {'text': ['Equilibrium Line Altitude', ' ''Equ...
# 101  {'text': ['Höhengrenze', ' eine Höhengrenze de...
# 102  {'text': ['im sogenannten Zehrgebiet (Ablation...
# 103  {'text': ['Nährgebiet', 'Akkumulationsgebiet',...
# 104  {'text': ['Zehrgebiet ', 'Ablationsgebiet', 'Z...
# 105  {'text': ['mehr Gletschereis gebildet als durc...
# 106  {'text': ['''Hatt-ı Şerif'' von Gülhane ', ' '...
# 107  {'text': ['1839', '1839', '1839'], 'answer_sta...
# 108  {'text': ['1856', '1856', '1856 '], 'answer_st...
# 109  {'text': ['1914–1923', '1914–1923', '1914–1923...
# 110  {'text': ['Deportationsgesetz von 1915', 'das ...
# 111  {'text': ['Armeniern', 'Armeniern', 'Armeniern...
# 112  {'text': ['Jungtürken', 'Jungtürken', 'Jungtür...
# 113  {'text': ['sieben', 'sieben', 'sieben '], 'ans...
# 114  {'text': ['drei', 'drei', 'drei '], 'answer_st...
# 115  {'text': ['männlich, weiblich und sächlich', '...
# 116  {'text': ['zwischen „belebt“ und „unbelebt“', ...
# 117  {'text': ['Wie im Lateinischen und den meisten...
# 118  {'text': ['Funktion eines Prädikativums', 'fas...
# 119  {'text': ['17. Juni 1963', '17. Juni 1963', 'a...
# 120  {'text': ['128', '128', '128 Zeichen'], 'answe...
# 121  {'text': ['das lateinische Alphabet in Groß- u...
# 122  {'text': ['33', '33', '33'], 'answer_start': [...
# 123  {'text': ['222 Millionen Euro', '222 Millionen...
# 124  {'text': ['Borussia Dortmund', 'Borussia Dortm...
# 125  {'text': ['vor allem Papierkondensatoren', 'vo...
# 126  {'text': ['1775', '1775', '1775'], 'answer_sta...
# 127  {'text': ['Der Auftrag der ''Army'', wie sie i...
# 128  {'text': ['Heer der Volksrepublik China, dem I...
# 129  {'text': ['südlich des Jangtsekiang-Deltas im ...
# 130  {'text': ['an Jiangsu und Shanghai', 'Jiangsu ...
# 131  {'text': ['an das Ostchinesische Meer', 'an da...
# 132  {'text': ['Fujian', 'Fujian'], 'answer_start':...
# 133  {'text': ['eine Ebene im Norden, Hügelland im ...
# 134  {'text': ['74,6 %', '74,6 %', '74,6 '], 'answe...
# 135  {'text': ['Drei', 'Drei', 'Drei '], 'answer_st...
# 136  {'text': ['1929 Metern', '1929', '1929 Metern'...
# 137  {'text': ['Huangmaojian', 'Huangmaojian', 'Hua...
# 138  {'text': ['Die wichtigsten Flüsse der Provinz ...
# 139  {'text': ['der Westsee bei Hangzhou, der Ostse...
# 140  {'text': ['2878', '2878', '2878'], 'answer_sta...
# 141  {'text': ['Auf molekularer Ebene besteht Eis a...
# 142  {'text': ['Wenn die Spannung, die auf die darü...
# 143  {'text': ['An der Gletschersohle sowie den Fla...
# 144  {'text': ['Texas', 'Texas', 'Texas '], 'answer...
# 145  {'text': ['am Golf von Mexiko in der Golfküste...
# 146  {'text': ['58 km2', '58 km2', '58 km2'], 'answ...
# 147  {'text': ['Harris County', 'im Harris County',...
# 148  {'text': ['Houston Ship Channel', 'Houston Shi...
# 149  {'text': ['Buffalo Bayou', 'Buffalo Bayou', 'B...

# %%
for sample in germanquad["test"]:
    print(sample["question"])
    print(sample["context"])
    print(sample["answers"])
    print()
    break
# Out:
# Was kann den Verschleiß des seillosen Aufzuges minimieren?
# Aufzugsanlage
#
# === Seilloser Aufzug ===
# An der RWTH Aachen im Institut für Elektrische Maschinen wurde ein seilloser Aufzug entwickelt und ein Prototyp aufgebaut. Die Kabine wird hierbei durch zwei elektromagnetische Synchron-Linearmotoren angetrieben und somit nur durch ein vertikal bewegliches Magnetfeld gehalten bzw. bewegt. Diese Arbeit soll der Entwicklung von Aufzugsanlagen für sehr hohe Gebäude dienen. Ein Ziel ist der Einsatz mehrerer Kabinen pro Schacht, die sich unabhängig voneinander steuern lassen. Bei Auswahl des Fahrtziels vor Fahrtantritt (d. h. noch außerhalb des Aufzug) wird ein bestimmter Fahrkorb in einem der Aufzugsschächte für die Fahrt ausgewählt, mit der sich der geplante Transport am schnellsten durchführen lässt. Der Platzbedarf für die gesamte Aufzugsanlage könnte somit um ein oder mehrere Schächte reduziert werden. Da die Kabinen seillos betrieben werden, ist ein Schachtwechsel ebenfalls denkbar. Hiermit können weitere Betriebsstrategien für die seillose Aufzugsanlage entwickelt werden, zum Beispiel ein moderner Paternosteraufzug mit unabhängig voneinander beweglichen Kabinen.
# Im Rahmen der Forschungen an dem seillosen Aufzug wird ebenfalls an der Entwicklung elektromagnetischer Linearführungen gearbeitet, um den Verschleiß der seillosen Aufzugsanlage bei hohem Fahrkomfort zu minimieren. Weltweit wird an verschiedenen Forschungseinrichtungen an seillosen Antriebslösungen für Aufzüge gearbeitet. Otis betreibt zu diesem Zweck seit 2007 den ''Shibayama Test Tower''. ThyssenKrupp Elevator weihte 2017 im süddeutschen Rottweil einen Testturm ein, in welchem die Technik des seillosen Aufzugs mit Synchron-Linearmotoren im Originalmaßstab getestet wird. Der erste Aufzug dieses Typs soll 2020 in Berlin in Betrieb gehen.
# {'text': ['elektromagnetischer Linearführungen', ' elektromagnetischer Linearführungen', 'elektromagnetischer Linearführungen'], 'answer_start': [1205, 1204, 1205]}

# %%
import evaluate

metric = evaluate.load("squad_v2")

# %%
theoretical_answers = [
    {"id": ex["id"], "answers": ex["answers"]} for ex in germanquad["test"].to_list()[:10]
]

# %%
theoretical_answers

# %%
predicted_answers = [
    {"id": ex["id"], "prediction_text": "tim"} for ex in theoretical_answers
]

# %%
germanquad["test"].to_list()[:2]

# %%
germanquad["test"]["context"].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 germanquad["test"]["context"].to_list()
#
# AttributeError: 'list' object has no attribute 'to_list'

# %%
# squad_v2_metric = evaluate.load("squad_v2")
# results = squad_v2_metric.compute(predictions=predictions, references=references)
# print(results)

# %%
print(metric.inputs_description)

# %%
predictions = [{'prediction_text': '', 'id': 'asdf', 'no_answer_probability': 1.}]
references = [{'answers': {'answer_start': [], 'text': []}, 'id': 'asdf'}]
squad_v2_metric = evaluate.load("squad_v2")
results = squad_v2_metric.compute(predictions=predictions, references=references)
print(results)
# Out:
# {'exact': 100.0, 'f1': 100.0, 'total': 1, 'NoAns_exact': 100.0, 'NoAns_f1': 100.0, 'NoAns_total': 1, 'best_exact': 100.0, 'best_exact_thresh': 0.0, 'best_f1': 100.0, 'best_f1_thresh': 0.0}

# %%
references

# %%
references = [{"answers": ex["answers"], "id": str(ex["id"])} for ex in germanquad["test"].to_list()[:1]]
predictions = [
    {"id": ex["id"], "prediction_text": "elektromagnetischer Linearführungen", "no_answer_probability": 0.0} for ex in references
]

# %%
references

# %%
predictions

# %%
squad_v2_metric = evaluate.load("squad_v2")
results = squad_v2_metric.compute(predictions=predictions, references=references)
print(results)

# %%
import pandas as pd

df = pd.read_parquet("experiments/extractive-qa/extractive_qa_squad2.parquet")

# %%
df
# Out:
#                                               Answer  \
# 0  {'answers': {'answer_start': [], 'text': []}, ...
# 1  {'answers': {'answer_start': [], 'text': []}, ...
# 2  {'answers': {'answer_start': [], 'text': []}, ...
# 3  {'answers': {'answer_start': [], 'text': []}, ...
#
#                                           Prediction  \
# 0  {'id': '5ad39d53604f3c001a3fe8d1', 'no_answer_...
# 1  {'id': '5ad39d53604f3c001a3fe8d2', 'no_answer_...
# 2  {'id': '5ad39d53604f3c001a3fe8d3', 'no_answer_...
# 3  {'id': '5ad39d53604f3c001a3fe8d4', 'no_answer_...
#
#                                               Reason  \
# 0                                The Normans (Norman
# 1  The Normans in the 10th and 11th centuries gav...
# 2  Through generations of assimilation and mixing...
# 3  The provided text does not mention when the Fr...
#
#                                              Message
# 0  Answer: The Normans \nReasoning:  The Normans ...
# 1  Answer: France\nReasoning:  The Normans in the...
# 2  Answer: Rollo \nReasoning:  Through generation...
# 3  Answer: Not answerable \nReasoning: The provid...

# %%
df[1:3]
# Out:
#                     Answer                                         Prediction  \
# 1        Carolina Panthers                                  Carolina Panthers
# 2  Santa Clara, California  Levi's Stadium in the San Francisco Bay Area a...
#
#                                               Reason  \
# 1  The American Football Conference (AFC) champio...
# 2                                    Not answerable.
#
#                                              Message
# 1  Answer: Carolina Panthers \nReasoning:  The Am...
# 2  Answer: Levi's Stadium in the San Francisco Ba...

# %%
df["Answer"] = df["Answer"].apply(lambda x: x["answers"]["text"][0])

# %%
df["Prediction"] = df["Prediction"].apply(lambda x: x["prediction_text"])
